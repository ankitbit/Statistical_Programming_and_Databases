# %%
# scikits.appspot.com/scikits
import numpy as np
import pylab as pl
# %pylab inline
from sklearn.datasets import load_sample_image

china = load_sample_image("china.jpg")
pl.imshow(china)
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
from sklearn.datasets import load_iris
iris_data = load_iris()

# target contains the target variables for the classification problem
target = iris_data["target"]
# data is an array of observations. We have to acces them maybe row wise for inspection
data = iris_data["data"]
# inspecting the shape of the data
print(data.shape)
iris_data.target_names
#ata.target_names(data.target)
iris_data.target_names[iris_data.target]
# Out:
# (150, 4)
# array(['setosa', 'setosa', 'setosa', 'setosa', 'setosa', 'setosa',
#        'setosa', 'setosa', 'setosa', 'setosa', 'setosa', 'setosa',
#        'setosa', 'setosa', 'setosa', 'setosa', 'setosa', 'setosa',
#        'setosa', 'setosa', 'setosa', 'setosa', 'setosa', 'setosa',
#        'setosa', 'setosa', 'setosa', 'setosa', 'setosa', 'setosa',
#        'setosa', 'setosa', 'setosa', 'setosa', 'setosa', 'setosa',
#        'setosa', 'setosa', 'setosa', 'setosa', 'setosa', 'setosa',
#        'setosa', 'setosa', 'setosa', 'setosa', 'setosa', 'setosa',
#        'setosa', 'setosa', 'versicolor', 'versicolor', 'versicolor',
#        'versicolor', 'versicolor', 'versicolor', 'versicolor',
#        'versicolor', 'versicolor', 'versicolor', 'versicolor',
#        'versicolor', 'versicolor', 'versicolor', 'versicolor',
#        'versicolor', 'versicolor', 'versicolor', 'versicolor',
#        'versicolor', 'versicolor', 'versicolor', 'versicolor',
#        'versicolor', 'versicolor', 'versicolor', 'versicolor',
#        'versicolor', 'versicolor', 'versicolor', 'versicolor',
#        'versicolor', 'versicolor', 'versicolor', 'versicolor',
#        'versicolor', 'versicolor', 'versicolor', 'versicolor',
#        'versicolor', 'versicolor', 'versicolor', 'versicolor',
#        'versicolor', 'versicolor', 'versicolor', 'versicolor',
#        'versicolor', 'versicolor', 'versicolor', 'virginica', 'virginica',
#        'virginica', 'virginica', 'virginica', 'virginica', 'virginica',
#        'virginica', 'virginica', 'virginica', 'virginica', 'virginica',
#        'virginica', 'virginica', 'virginica', 'virginica', 'virginica',
#        'virginica', 'virginica', 'virginica', 'virginica', 'virginica',
#        'virginica', 'virginica', 'virginica', 'virginica', 'virginica',
#        'virginica', 'virginica', 'virginica', 'virginica', 'virginica',
#        'virginica', 'virginica', 'virginica', 'virginica', 'virginica',
#        'virginica', 'virginica', 'virginica', 'virginica', 'virginica',
#        'virginica', 'virginica', 'virginica', 'virginica', 'virginica',
#        'virginica', 'virginica', 'virginica'],
#       dtype='|S10')

# %%
# multiclass ,  two informative features and one cluster data generation
from sklearn.datasets import make_classification
(classification_data,y) = make_classification(n_samples = 50, n_features=2,n_informative=2, 
                                              n_redundant=0,n_classes=4, n_clusters_per_class=1,
                                             )

pl.scatter(classification_data[:,0], classification_data[:,1],c=y)

# %%
import numpy as np
def rot(angle, R = np.zeros((3,3))):
        cx, cy, cz = np.cos(angle)
        sx, sy, sz = np.sin(angle)
        R.flat = (cx*cz - sx*cy*sz, cx*sz + sx*cy*cz, sx*sy, -sx*cz - cx*cy*sz, -sx*sz + cx*cy*cz, cx*sy, sy*sz, -sy*cz, cy)
        return R

# %%
# plotting swiss rolls in 3 D
import mpl_toolkits.mplot3d.axes3d as p3
import pylab as pl
def myplot(X, col = "blue"):
    fig = pl.figure()
    ax = p3.Axes3D(fig)
    ax.view_init(7, -80)
    ax.scatter( X[:, 0], X[:, 1], X[:, 2], s= 10, c=col, marker="o")

# %%
rotate_swiss_roll = rot((0,np.pi/4,np.pi/4))

# %%
from sklearn.datasets import make_swiss_roll
swiss_roll1, _ = make_swiss_roll(1000)
swiss_roll2, _ = make_swiss_roll(1000)

X = np.concatenate( (swiss_roll1, swiss_roll2.dot(rotate_swiss_roll) + 30 ) )
myplot(X)

# %%
rotate_swiss_roll.transpose().shape
swiss_roll.shape
product
# Out:
# array([[ -3.03116986e+00,  -5.64045475e+00,   8.98595402e+00],
#        [ -6.13498617e+00,   1.40143970e+01,   4.55452853e+00],
#        [ -9.46058730e+00,   9.46777280e+00,   1.37554836e+01],
#        [  3.32193041e+00,  -2.41670787e-01,   1.01181654e+01],
#        [ -3.20736715e+00,   1.16764140e+01,   1.59545284e+01],
#        [ -3.81404687e+00,   9.84985788e+00,   9.53741373e+00],
#        [  5.10549343e+00,   3.88591062e+00,   8.81537346e-01],
#        [ -2.70091070e+00,   1.40500243e+00,   2.08614231e+01],
#        [ -4.21561871e+00,  -2.51218397e+00,   1.60579356e+01],
#        [ -1.60144079e+01,   3.08466005e+00,   1.63866320e+01],
#        [ -2.05227451e+00,  -6.81484733e+00,   6.12334744e+00],
#        [ -6.38022997e+00,   9.12844658e+00,  -3.00602549e+00],
#        [ -1.10655280e+00,   9.90682438e+00,   1.81180457e+01],
#        [  6.46292501e+00,   1.02934804e+01,   1.53331247e+01],
#        [ -2.53581621e+00,   4.33016826e+00,  -1.20260729e+00],
#        [ -1.20806501e+01,   1.26393824e+01,   8.22709446e+00],
#        [ -6.22487878e+00,  -2.47235452e+00,   1.67485644e+01],
#        [ -1.60665072e+01,   4.05982301e+00,   1.41656156e+01],
#        [ -2.05138245e+00,   1.03264029e+01,   1.22003487e+01],
#        [  4.70331402e+00,   4.19605772e+00,   3.22049720e+00],
#        [  5.84560801e+00,   1.06802074e+01,  -1.49164932e+00],
#        [  1.07866293e+01,  -5.01962816e+00,   7.08846024e+00],
#        [  5.41330804e+00,  -3.39086786e+00,   4.28068562e+00],
#        [ -6.60659549e+00,   1.04119821e+01,  -9.77504094e-01],
#        [  5.17819112e+00,   1.16773902e+01,   1.82012825e+01],
#        [  8.18041320e+00,   7.39348550e+00,   1.33872208e+01],
#        [ -3.65222930e+00,   9.25433031e+00,   8.13613967e+00],
#        [ -7.86185770e+00,   1.04471699e+01,   1.29435348e+01],
#        [  3.65529840e+00,   5.26866743e+00,   2.35238772e+00],
#        [  9.56473950e+00,   7.19019248e+00,   7.73924919e+00],
#        [ -3.23303740e+00,   9.61125558e+00,   8.96024682e+00],
#        [ -8.11881876e+00,  -9.18060513e-01,   2.05717501e+01],
#        [  7.35031525e+00,   1.60899153e-01,   1.65393267e+01],
#        [ -8.52381555e+00,  -4.57961912e+00,  -1.15803871e+00],
#        [ -1.07604349e+01,   1.44996049e+01,   9.10194245e+00],
#        [  3.81915444e+00,  -2.00239196e+00,   8.02596227e+00],
#        [ -1.12514795e+01,   1.41905437e+01,   9.18459839e+00],
#        [  6.10781763e+00,   1.16796198e+01,   7.13044209e+00],
#        [ -8.76602919e+00,   9.95083969e+00,   1.32986474e+01],
#        [ -4.74287723e+00,   1.65412245e+01,   9.42753888e+00],
#        [  5.45548514e+00,  -3.37599849e+00,   1.70935469e+01],
#        [ -4.14969874e-01,   1.19735321e+01,  -1.74872138e+00],
#        [  5.99790896e+00,  -1.02476824e+00,   4.31992272e+00],
#        [  3.95971087e+00,   1.17645890e+01,  -2.43905712e-01],
#        [  1.03206643e+00,   5.61324178e+00,  -7.89931362e-01],
#        [ -3.78866932e+00,  -7.35234817e+00,   4.06145991e+00],
#        [  1.07423538e+01,   3.50384932e+00,   8.42826768e+00],
#        [  9.03404901e-01,   2.96450148e+00,   1.64476248e+01],
#        [  2.16380551e+00,   2.20735430e+00,   1.35546368e+01],
#        [  2.62685411e+00,   5.27489160e+00,  -7.76590441e-01],
#        [ -2.85382579e+00,   4.11037278e+00,  -1.09783863e+00],
#        [ -1.30415444e+01,   1.48396205e+01,   1.20727666e+01],
#        [  1.79391520e+00,   6.85220007e+00,   1.17106679e+01],
#        [  5.07971270e+00,   1.00467540e+00,   6.59322597e+00],
#        [ -8.00672153e+00,  -5.16794839e+00,   4.95964986e+00],
#        [ -6.54338280e+00,   1.00983725e+01,   1.12428503e+01],
#        [ -1.09193972e+01,  -4.39294406e-02,   2.99021944e-01],
#        [ -7.79508248e-01,   9.24778308e+00,   1.00035802e+01],
#        [ -1.67269124e+01,   7.05426846e+00,   1.38131083e+01],
#        [ -1.04242651e+01,   1.53311560e+01,   1.00199005e+01],
#        [ -4.63124670e-01,   7.06040194e+00,   2.74453219e+00],
#        [ -4.04521083e+00,  -4.35501056e+00,   1.20997545e+01],
#        [ -9.20528500e+00,   1.33191982e+01,   5.83754546e+00],
#        [ -6.54343174e+00,  -1.86817109e+00,   1.81930513e+01],
#        [ -2.33036725e+00,   5.65531443e+00,   5.41848371e-01],
#        [ -8.63444944e+00,  -4.38999502e+00,  -1.28234230e+00],
#        [ -7.44415068e+00,   7.02432572e+00,  -4.20878401e+00],
#        [ -1.11272502e+01,  -2.26688402e+00,   8.17601286e+00],
#        [  7.52637583e+00,   2.07724008e+00,   1.69273084e+01],
#        [ -1.37528302e+01,   3.82790524e+00,   6.61660909e+00],
#        [  9.99859838e+00,   4.77419418e+00,   9.82848353e+00],
#        [ -4.25105955e+00,   1.24281802e+01,   1.71633966e+01],
#        [ -1.12712200e+00,   9.36547474e+00,   9.77448977e+00],
#        [  3.80479333e+00,   1.31027059e+01,   5.42207665e+00],
#        [ -3.24303086e+00,  -3.57610390e+00,   1.34957608e+01],
#        [ -1.14752832e+00,   1.00151223e+01,   1.35162664e+01],
#        [  7.42649930e+00,   4.58490589e+00,   1.73881109e+01],
#        [  2.11460121e+00,  -3.64687179e+00,   8.77606938e+00],
#        [  3.81337938e-01,   1.14971711e+01,  -2.92948563e+00],
#        [ -4.41143648e+00,   1.30802019e+01,   1.83313342e+00],
#        [  7.16237622e+00,   9.26779524e+00,   1.44103043e+01],
#        [ -1.04726052e+01,   4.56843839e+00,  -1.04403144e+00],
#        [ -4.70148148e+00,   1.65955899e+01,   9.55885911e+00],
#        [  3.52582478e+00,  -5.17970297e+00,   5.16744075e+00],
#        [  4.62775258e+00,   1.14616926e+00,   7.73365611e+00],
#        [  6.23647707e+00,   9.22809160e+00,   1.82929396e+01],
#        [ -2.89576373e+00,  -6.74064157e+00,   6.26019688e+00],
#        [  6.42264083e+00,  -7.05282392e-02,   1.81569275e+01],
#        [ -1.08427937e+01,   1.03715046e+01,   4.06187787e+00],
#        [ -1.58417010e+01,   9.69300948e+00,   1.20008996e+01],
#        [ -6.52182935e-03,   7.23866147e+00,   3.42677368e+00],
#        [  1.13726476e+01,  -2.51891243e+00,   7.27067708e+00],
#        [ -8.60274241e+00,  -2.67356758e+00,   1.54038268e+01],
#        [ -1.52373005e+01,   4.61136302e+00,   1.06211392e+01],
#        [ -6.67038935e+00,  -1.17362154e+00,   1.97693185e+01],
#        [ -4.30170752e-01,   8.17182575e+00,   1.90873713e+01],
#        [  1.22509722e+01,   2.52400602e+00,   4.30932500e+00],
#        [ -1.12039209e+01,   2.07157878e-01,   1.02442515e+00],
#        [ -7.38993816e+00,   7.57123560e+00,   8.84820670e+00],
#        [ -1.61540841e+01,   9.45401923e+00,   1.25579584e+01]])

# %%
myplot(product)
